# %% [markdown]
# # Mask R-CNN - Train on Shapes Dataset
#
#
# This notebook shows how to train Mask R-CNN on your own dataset. To keep things simple we use a synthetic dataset of shapes (squares, triangles, and circles) which enables fast training. You'd still need a GPU, though, because the network backbone is a Resnet101, which would be too slow to train on a CPU. On a GPU, you can start to get okay-ish results in a few minutes, and good results in less than an hour.
#
# The code of the *Shapes* dataset is included below. It generates images on the fly, so it doesn't require downloading any data. And it can generate images of any size, so we pick a small image size to train faster.

# %%
import os
import json
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import clear_output


sys.path.append('C:/Users/yliu60/Documents/GitHub/amodalAPI/PythonAPI/pycocotools')
sys.path.append('C:/Users/Yanfeng Liu/Documents/GitHub/amodalAPI/PythonAPI/pycocotools')

import mask as Mask

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn.model import log
from mrcnn import utils
from mrcnn import visualize
from PIL import Image, ImageDraw
import mrcnn_shapes as shapes_lib
import mrcnn.model as modellib
# %matplotlib inline 

import metrics_hist
import params as params_lib
import batchEval
from experiment import get_mrcnn_result_list

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

from importlib import reload
_ = reload(shapes_lib)
_ = reload(visualize)
_ = reload(modellib)
_ = reload(metrics_hist)

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# The GPU id to use
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
num_instances_per_class = 6

# %%
class ShapesConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2

    # Number of classes (including background)
    NUM_CLASSES = 1 + 3  # background + 3 shapes

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    
    IMAGE_RESIZE_MODE = "none"

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 64

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 1000

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 100
    
    LEARNING_RATE = 1e-4
    
    # custom properties
    FULL_GT = True
    SMALL = True
    RANDOM = False
    DATASET_TYPE = 'val'
    DATASET_NAME = 'shapes'
    DT_DIR = 'C:/Users/yliu60/Documents/GitHub/Pixel-Embedding/results/mrcnn/6-1_2_3/'
    GT_JSON_DIR = 'C:/Users/yliu60/Documents/GitHub/Pixel-Embedding/gt_json/mrcnn/6/shapes_val_small_6.json'
    DOWNSAMPLE_FACTOR = 4
    DOWNSAMPLE_RESOLUTION = 64
    
config = ShapesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DATASET_NAME                   shapes
# DATASET_TYPE                   val
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# DOWNSAMPLE_FACTOR              4
# DOWNSAMPLE_RESOLUTION          64
# DT_DIR                         C:/Users/yliu60/Documents/GitHub/Pixel-Embedding/results/mrcnn/6-1_2_3/
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# FULL_GT                        True
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# GT_JSON_DIR                    C:/Users/yliu60/Documents/GitHub/Pixel-Embedding/gt_json/mrcnn/6/shapes_val_small_6.json
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              none
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.0001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           shapes
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# RANDOM                         False
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# SMALL                          True
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           64
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               100
# WEIGHT_DECAY                   0.0001

# %%
np.random.seed(num_instances_per_class)
# Validation dataset
dataset_val = shapes_lib.ShapesDataset(num_instances_per_class)
dataset_val.load_shapes(1000, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_val.prepare()
config.MRCNN_DATASET = dataset_val

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
class InferenceConfig(ShapesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %%
EPOCHS = 100
hist = metrics_hist.MetricsHist(config.DT_DIR)
# get new training dataset at every epoch
dataset_train = shapes_lib.ShapesDataset(num_instances_per_class)
dataset_train.load_shapes(1, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_train.prepare()

# %%
model.epoch = 0
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE,
            epochs=EPOCHS,
            layers="all")
# Out:
# Starting at epoch 0. LR=0.0001
#
# Checkpoint Path: C:\Users\yliu60\Documents\GitHub\Pixel-Embedding\logs\shapes20190302T1108\mask_rcnn_shapes_0.h5
# Selecting layers to train
# Epoch 1/100
# 1000/1000 [==============================] - 746s 746ms/step - loss: 1.5736 - rpn_class_loss: 0.0165 - rpn_bbox_loss: 0.4588 - mrcnn_class_loss: 0.4868 - mrcnn_bbox_loss: 0.3125 - mrcnn_mask_loss: 0.2991 - val_loss: 1.2012 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.3166 - val_mrcnn_class_loss: 0.3935 - val_mrcnn_bbox_loss: 0.2358 - val_mrcnn_mask_loss: 0.2450
# Epoch 2/100
# 1000/1000 [==============================] - 674s 674ms/step - loss: 1.1656 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.3123 - mrcnn_class_loss: 0.3802 - mrcnn_bbox_loss: 0.2249 - mrcnn_mask_loss: 0.2391 - val_loss: 1.1057 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.3072 - val_mrcnn_class_loss: 0.3510 - val_mrcnn_bbox_loss: 0.2103 - val_mrcnn_mask_loss: 0.2300
# Epoch 3/100
# 1000/1000 [==============================] - 668s 668ms/step - loss: 1.0454 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.2781 - mrcnn_class_loss: 0.3427 - mrcnn_bbox_loss: 0.1963 - mrcnn_mask_loss: 0.2207 - val_loss: 0.9705 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.2475 - val_mrcnn_class_loss: 0.3174 - val_mrcnn_bbox_loss: 0.1823 - val_mrcnn_mask_loss: 0.2154
# Epoch 4/100
# 1000/1000 [==============================] - 663s 663ms/step - loss: 0.9706 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.2609 - mrcnn_class_loss: 0.3184 - mrcnn_bbox_loss: 0.1787 - mrcnn_mask_loss: 0.2062 - val_loss: 0.9088 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.2509 - val_mrcnn_class_loss: 0.2990 - val_mrcnn_bbox_loss: 0.1571 - val_mrcnn_mask_loss: 0.1963
# Epoch 5/100
# 1000/1000 [==============================] - 668s 668ms/step - loss: 0.9026 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.2386 - mrcnn_class_loss: 0.2974 - mrcnn_bbox_loss: 0.1659 - mrcnn_mask_loss: 0.1949 - val_loss: 0.9115 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.2402 - val_mrcnn_class_loss: 0.3090 - val_mrcnn_bbox_loss: 0.1616 - val_mrcnn_mask_loss: 0.1958
# Epoch 6/100
# 1000/1000 [==============================] - 671s 671ms/step - loss: 0.8694 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.2350 - mrcnn_class_loss: 0.2860 - mrcnn_bbox_loss: 0.1567 - mrcnn_mask_loss: 0.1860 - val_loss: 0.8711 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.2305 - val_mrcnn_class_loss: 0.2869 - val_mrcnn_bbox_loss: 0.1586 - val_mrcnn_mask_loss: 0.1892
# Epoch 7/100
# 1000/1000 [==============================] - 665s 665ms/step - loss: 0.8427 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.2207 - mrcnn_class_loss: 0.2827 - mrcnn_bbox_loss: 0.1508 - mrcnn_mask_loss: 0.1834 - val_loss: 0.8061 - val_rpn_class_loss: 0.0038 - val_rpn_bbox_loss: 0.2091 - val_mrcnn_class_loss: 0.2626 - val_mrcnn_bbox_loss: 0.1537 - val_mrcnn_mask_loss: 0.1770
# Epoch 8/100
# 1000/1000 [==============================] - 669s 669ms/step - loss: 0.8242 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.2162 - mrcnn_class_loss: 0.2782 - mrcnn_bbox_loss: 0.1471 - mrcnn_mask_loss: 0.1777 - val_loss: 0.8265 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.2039 - val_mrcnn_class_loss: 0.2852 - val_mrcnn_bbox_loss: 0.1532 - val_mrcnn_mask_loss: 0.1801
# Epoch 9/100
# 1000/1000 [==============================] - 678s 678ms/step - loss: 0.7953 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.2101 - mrcnn_class_loss: 0.2616 - mrcnn_bbox_loss: 0.1436 - mrcnn_mask_loss: 0.1753 - val_loss: 0.7650 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.1975 - val_mrcnn_class_loss: 0.2500 - val_mrcnn_bbox_loss: 0.1365 - val_mrcnn_mask_loss: 0.1760
# Epoch 10/100
# 1000/1000 [==============================] - 682s 682ms/step - loss: 0.7770 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.2064 - mrcnn_class_loss: 0.2572 - mrcnn_bbox_loss: 0.1375 - mrcnn_mask_loss: 0.1714 - val_loss: 0.7327 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 0.1998 - val_mrcnn_class_loss: 0.2397 - val_mrcnn_bbox_loss: 0.1263 - val_mrcnn_mask_loss: 0.1621
# Epoch 11/100
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.7518 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.2006 - mrcnn_class_loss: 0.2491 - mrcnn_bbox_loss: 0.1323 - mrcnn_mask_loss: 0.1653 - val_loss: 0.7886 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.2284 - val_mrcnn_class_loss: 0.2511 - val_mrcnn_bbox_loss: 0.1337 - val_mrcnn_mask_loss: 0.1702
# Epoch 12/100
# 1000/1000 [==============================] - 677s 677ms/step - loss: 0.7421 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.2002 - mrcnn_class_loss: 0.2442 - mrcnn_bbox_loss: 0.1287 - mrcnn_mask_loss: 0.1646 - val_loss: 0.7193 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.1821 - val_mrcnn_class_loss: 0.2451 - val_mrcnn_bbox_loss: 0.1286 - val_mrcnn_mask_loss: 0.1596
# Epoch 13/100
# 1000/1000 [==============================] - 662s 662ms/step - loss: 0.7328 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.1958 - mrcnn_class_loss: 0.2437 - mrcnn_bbox_loss: 0.1267 - mrcnn_mask_loss: 0.1623 - val_loss: 0.7382 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.1788 - val_mrcnn_class_loss: 0.2547 - val_mrcnn_bbox_loss: 0.1354 - val_mrcnn_mask_loss: 0.1651
# Epoch 14/100
# 1000/1000 [==============================] - 650s 650ms/step - loss: 0.7216 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.1926 - mrcnn_class_loss: 0.2382 - mrcnn_bbox_loss: 0.1260 - mrcnn_mask_loss: 0.1606 - val_loss: 0.7064 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 0.1913 - val_mrcnn_class_loss: 0.2300 - val_mrcnn_bbox_loss: 0.1232 - val_mrcnn_mask_loss: 0.1555
# Epoch 15/100
# 1000/1000 [==============================] - 650s 650ms/step - loss: 0.7017 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.1898 - mrcnn_class_loss: 0.2290 - mrcnn_bbox_loss: 0.1217 - mrcnn_mask_loss: 0.1575 - val_loss: 0.7174 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.1953 - val_mrcnn_class_loss: 0.2349 - val_mrcnn_bbox_loss: 0.1248 - val_mrcnn_mask_loss: 0.1590
# Epoch 16/100
# 1000/1000 [==============================] - 687s 687ms/step - loss: 0.7045 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1876 - mrcnn_class_loss: 0.2321 - mrcnn_bbox_loss: 0.1238 - mrcnn_mask_loss: 0.1571 - val_loss: 0.7176 - val_rpn_class_loss: 0.0038 - val_rpn_bbox_loss: 0.1844 - val_mrcnn_class_loss: 0.2499 - val_mrcnn_bbox_loss: 0.1226 - val_mrcnn_mask_loss: 0.1568
# Epoch 17/100
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.6813 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1837 - mrcnn_class_loss: 0.2233 - mrcnn_bbox_loss: 0.1177 - mrcnn_mask_loss: 0.1527 - val_loss: 0.6763 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.1748 - val_mrcnn_class_loss: 0.2285 - val_mrcnn_bbox_loss: 0.1151 - val_mrcnn_mask_loss: 0.1537
# Epoch 18/100
# 1000/1000 [==============================] - 689s 689ms/step - loss: 0.6773 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.1811 - mrcnn_class_loss: 0.2246 - mrcnn_bbox_loss: 0.1165 - mrcnn_mask_loss: 0.1513 - val_loss: 0.6599 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.1750 - val_mrcnn_class_loss: 0.2144 - val_mrcnn_bbox_loss: 0.1131 - val_mrcnn_mask_loss: 0.1534
# Epoch 19/100
# 1000/1000 [==============================] - 683s 683ms/step - loss: 0.6725 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1790 - mrcnn_class_loss: 0.2247 - mrcnn_bbox_loss: 0.1160 - mrcnn_mask_loss: 0.1488 - val_loss: 0.6584 - val_rpn_class_loss: 0.0036 - val_rpn_bbox_loss: 0.1690 - val_mrcnn_class_loss: 0.2252 - val_mrcnn_bbox_loss: 0.1131 - val_mrcnn_mask_loss: 0.1476
# Epoch 20/100
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.6688 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1813 - mrcnn_class_loss: 0.2196 - mrcnn_bbox_loss: 0.1147 - mrcnn_mask_loss: 0.1493 - val_loss: 0.6974 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.1773 - val_mrcnn_class_loss: 0.2352 - val_mrcnn_bbox_loss: 0.1244 - val_mrcnn_mask_loss: 0.1571
# Epoch 21/100
# 1000/1000 [==============================] - 694s 694ms/step - loss: 0.6618 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.1777 - mrcnn_class_loss: 0.2181 - mrcnn_bbox_loss: 0.1141 - mrcnn_mask_loss: 0.1481 - val_loss: 0.6565 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.1690 - val_mrcnn_class_loss: 0.2205 - val_mrcnn_bbox_loss: 0.1150 - val_mrcnn_mask_loss: 0.1482
# Epoch 22/100
# 1000/1000 [==============================] - 692s 692ms/step - loss: 0.6444 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.1724 - mrcnn_class_loss: 0.2105 - mrcnn_bbox_loss: 0.1120 - mrcnn_mask_loss: 0.1460 - val_loss: 0.6367 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.1764 - val_mrcnn_class_loss: 0.2032 - val_mrcnn_bbox_loss: 0.1090 - val_mrcnn_mask_loss: 0.1448
# Epoch 23/100
# 1000/1000 [==============================] - 690s 690ms/step - loss: 0.6573 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.1740 - mrcnn_class_loss: 0.2209 - mrcnn_bbox_loss: 0.1114 - mrcnn_mask_loss: 0.1473 - val_loss: 0.6509 - val_rpn_class_loss: 0.0036 - val_rpn_bbox_loss: 0.1592 - val_mrcnn_class_loss: 0.2324 - val_mrcnn_bbox_loss: 0.1103 - val_mrcnn_mask_loss: 0.1454
# Epoch 24/100
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.6533 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.1778 - mrcnn_class_loss: 0.2162 - mrcnn_bbox_loss: 0.1094 - mrcnn_mask_loss: 0.1460 - val_loss: 0.6372 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.1655 - val_mrcnn_class_loss: 0.2167 - val_mrcnn_bbox_loss: 0.1060 - val_mrcnn_mask_loss: 0.1454
# Epoch 25/100
# 1000/1000 [==============================] - 679s 679ms/step - loss: 0.6324 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.1677 - mrcnn_class_loss: 0.2095 - mrcnn_bbox_loss: 0.1076 - mrcnn_mask_loss: 0.1440 - val_loss: 0.6339 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.1649 - val_mrcnn_class_loss: 0.2095 - val_mrcnn_bbox_loss: 0.1088 - val_mrcnn_mask_loss: 0.1460
# Epoch 26/100
# 1000/1000 [==============================] - 678s 678ms/step - loss: 0.6236 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.1667 - mrcnn_class_loss: 0.2067 - mrcnn_bbox_loss: 0.1060 - mrcnn_mask_loss: 0.1406 - val_loss: 0.6473 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.1619 - val_mrcnn_class_loss: 0.2277 - val_mrcnn_bbox_loss: 0.1097 - val_mrcnn_mask_loss: 0.1435
# Epoch 27/100
# 1000/1000 [==============================] - 676s 676ms/step - loss: 0.6287 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.1653 - mrcnn_class_loss: 0.2104 - mrcnn_bbox_loss: 0.1067 - mrcnn_mask_loss: 0.1428 - val_loss: 0.6348 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.1736 - val_mrcnn_class_loss: 0.2037 - val_mrcnn_bbox_loss: 0.1082 - val_mrcnn_mask_loss: 0.1461
# Epoch 28/100
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.6212 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.1699 - mrcnn_class_loss: 0.2038 - mrcnn_bbox_loss: 0.1042 - mrcnn_mask_loss: 0.1399 - val_loss: 0.6200 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.1750 - val_mrcnn_class_loss: 0.2002 - val_mrcnn_bbox_loss: 0.0979 - val_mrcnn_mask_loss: 0.1430
# Epoch 29/100
# 1000/1000 [==============================] - 679s 679ms/step - loss: 0.6207 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.1660 - mrcnn_class_loss: 0.2060 - mrcnn_bbox_loss: 0.1040 - mrcnn_mask_loss: 0.1416 - val_loss: 0.5887 - val_rpn_class_loss: 0.0033 - val_rpn_bbox_loss: 0.1650 - val_mrcnn_class_loss: 0.1935 - val_mrcnn_bbox_loss: 0.0947 - val_mrcnn_mask_loss: 0.1322
# Epoch 30/100
# 1000/1000 [==============================] - 683s 683ms/step - loss: 0.6057 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.1611 - mrcnn_class_loss: 0.1999 - mrcnn_bbox_loss: 0.1022 - mrcnn_mask_loss: 0.1391 - val_loss: 0.5940 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.1598 - val_mrcnn_class_loss: 0.1953 - val_mrcnn_bbox_loss: 0.0986 - val_mrcnn_mask_loss: 0.1374
# Epoch 31/100
# 1000/1000 [==============================] - 684s 684ms/step - loss: 0.6151 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.1627 - mrcnn_class_loss: 0.2066 - mrcnn_bbox_loss: 0.1036 - mrcnn_mask_loss: 0.1389 - val_loss: 0.6316 - val_rpn_class_loss: 0.0033 - val_rpn_bbox_loss: 0.1716 - val_mrcnn_class_loss: 0.2074 - val_mrcnn_bbox_loss: 0.1070 - val_mrcnn_mask_loss: 0.1424
# Epoch 32/100
# 1000/1000 [==============================] - 674s 674ms/step - loss: 0.6153 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.1646 - mrcnn_class_loss: 0.2021 - mrcnn_bbox_loss: 0.1045 - mrcnn_mask_loss: 0.1407 - val_loss: 0.6043 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.1569 - val_mrcnn_class_loss: 0.2009 - val_mrcnn_bbox_loss: 0.1000 - val_mrcnn_mask_loss: 0.1432
# Epoch 33/100
# 1000/1000 [==============================] - 682s 682ms/step - loss: 0.6131 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.1625 - mrcnn_class_loss: 0.2041 - mrcnn_bbox_loss: 0.1038 - mrcnn_mask_loss: 0.1393 - val_loss: 0.5943 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.1634 - val_mrcnn_class_loss: 0.1978 - val_mrcnn_bbox_loss: 0.0986 - val_mrcnn_mask_loss: 0.1306
# Epoch 34/100
# 1000/1000 [==============================] - 675s 675ms/step - loss: 0.6027 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.1592 - mrcnn_class_loss: 0.2011 - mrcnn_bbox_loss: 0.1017 - mrcnn_mask_loss: 0.1373 - val_loss: 0.5770 - val_rpn_class_loss: 0.0030 - val_rpn_bbox_loss: 0.1523 - val_mrcnn_class_loss: 0.1966 - val_mrcnn_bbox_loss: 0.0937 - val_mrcnn_mask_loss: 0.1314
# Epoch 35/100
# 1000/1000 [==============================] - 680s 680ms/step - loss: 0.5958 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.1570 - mrcnn_class_loss: 0.1995 - mrcnn_bbox_loss: 0.1002 - mrcnn_mask_loss: 0.1359 - val_loss: 0.6015 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.1536 - val_mrcnn_class_loss: 0.2020 - val_mrcnn_bbox_loss: 0.1025 - val_mrcnn_mask_loss: 0.1405
# Epoch 36/100
# 1000/1000 [==============================] - 679s 679ms/step - loss: 0.5882 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.1530 - mrcnn_class_loss: 0.1987 - mrcnn_bbox_loss: 0.0976 - mrcnn_mask_loss: 0.1357 - val_loss: 0.5909 - val_rpn_class_loss: 0.0030 - val_rpn_bbox_loss: 0.1513 - val_mrcnn_class_loss: 0.2013 - val_mrcnn_bbox_loss: 0.0986 - val_mrcnn_mask_loss: 0.1366
# Epoch 37/100
# 1000/1000 [==============================] - 677s 677ms/step - loss: 0.5895 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.1553 - mrcnn_class_loss: 0.1985 - mrcnn_bbox_loss: 0.0973 - mrcnn_mask_loss: 0.1353 - val_loss: 0.5667 - val_rpn_class_loss: 0.0030 - val_rpn_bbox_loss: 0.1472 - val_mrcnn_class_loss: 0.1823 - val_mrcnn_bbox_loss: 0.0999 - val_mrcnn_mask_loss: 0.1343
# Epoch 38/100
# 1000/1000 [==============================] - 672s 672ms/step - loss: 0.5865 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.1572 - mrcnn_class_loss: 0.1948 - mrcnn_bbox_loss: 0.0986 - mrcnn_mask_loss: 0.1328 - val_loss: 0.5962 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.1555 - val_mrcnn_class_loss: 0.1968 - val_mrcnn_bbox_loss: 0.1020 - val_mrcnn_mask_loss: 0.1382
# Epoch 39/100
# 1000/1000 [==============================] - 663s 663ms/step - loss: 0.5812 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1539 - mrcnn_class_loss: 0.1946 - mrcnn_bbox_loss: 0.0977 - mrcnn_mask_loss: 0.1321 - val_loss: 0.5878 - val_rpn_class_loss: 0.0026 - val_rpn_bbox_loss: 0.1477 - val_mrcnn_class_loss: 0.2033 - val_mrcnn_bbox_loss: 0.0973 - val_mrcnn_mask_loss: 0.1369
# Epoch 40/100
# 1000/1000 [==============================] - 678s 678ms/step - loss: 0.5843 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.1557 - mrcnn_class_loss: 0.1966 - mrcnn_bbox_loss: 0.0965 - mrcnn_mask_loss: 0.1322 - val_loss: 0.5784 - val_rpn_class_loss: 0.0026 - val_rpn_bbox_loss: 0.1542 - val_mrcnn_class_loss: 0.1919 - val_mrcnn_bbox_loss: 0.0973 - val_mrcnn_mask_loss: 0.1323
# Epoch 41/100
# 1000/1000 [==============================] - 683s 683ms/step - loss: 0.5848 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.1545 - mrcnn_class_loss: 0.1966 - mrcnn_bbox_loss: 0.0974 - mrcnn_mask_loss: 0.1332 - val_loss: 0.5711 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.1617 - val_mrcnn_class_loss: 0.1858 - val_mrcnn_bbox_loss: 0.0892 - val_mrcnn_mask_loss: 0.1304
# Epoch 42/100
# 1000/1000 [==============================] - 686s 686ms/step - loss: 0.5704 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.1520 - mrcnn_class_loss: 0.1906 - mrcnn_bbox_loss: 0.0938 - mrcnn_mask_loss: 0.1308 - val_loss: 0.5889 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.1443 - val_mrcnn_class_loss: 0.2016 - val_mrcnn_bbox_loss: 0.1002 - val_mrcnn_mask_loss: 0.1395
# Epoch 43/100
# 1000/1000 [==============================] - 688s 688ms/step - loss: 0.5736 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1537 - mrcnn_class_loss: 0.1907 - mrcnn_bbox_loss: 0.0940 - mrcnn_mask_loss: 0.1321 - val_loss: 0.5613 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.1490 - val_mrcnn_class_loss: 0.1809 - val_mrcnn_bbox_loss: 0.0975 - val_mrcnn_mask_loss: 0.1311
# Epoch 44/100
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.5695 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.1513 - mrcnn_class_loss: 0.1905 - mrcnn_bbox_loss: 0.0941 - mrcnn_mask_loss: 0.1305 - val_loss: 0.5686 - val_rpn_class_loss: 0.0033 - val_rpn_bbox_loss: 0.1579 - val_mrcnn_class_loss: 0.1879 - val_mrcnn_bbox_loss: 0.0929 - val_mrcnn_mask_loss: 0.1266
# Epoch 45/100
# 1000/1000 [==============================] - 679s 679ms/step - loss: 0.5674 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1504 - mrcnn_class_loss: 0.1917 - mrcnn_bbox_loss: 0.0924 - mrcnn_mask_loss: 0.1299 - val_loss: 0.5808 - val_rpn_class_loss: 0.0033 - val_rpn_bbox_loss: 0.1510 - val_mrcnn_class_loss: 0.2039 - val_mrcnn_bbox_loss: 0.0926 - val_mrcnn_mask_loss: 0.1300
# Epoch 46/100
# 1000/1000 [==============================] - 671s 671ms/step - loss: 0.5698 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.1524 - mrcnn_class_loss: 0.1905 - mrcnn_bbox_loss: 0.0937 - mrcnn_mask_loss: 0.1301 - val_loss: 0.5748 - val_rpn_class_loss: 0.0027 - val_rpn_bbox_loss: 0.1492 - val_mrcnn_class_loss: 0.1976 - val_mrcnn_bbox_loss: 0.0950 - val_mrcnn_mask_loss: 0.1302
# Epoch 47/100
# 1000/1000 [==============================] - 678s 678ms/step - loss: 0.5657 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.1530 - mrcnn_class_loss: 0.1893 - mrcnn_bbox_loss: 0.0911 - mrcnn_mask_loss: 0.1294 - val_loss: 0.5902 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.1811 - val_mrcnn_class_loss: 0.1867 - val_mrcnn_bbox_loss: 0.0902 - val_mrcnn_mask_loss: 0.1281
# Epoch 48/100
# 1000/1000 [==============================] - 682s 682ms/step - loss: 0.5530 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1493 - mrcnn_class_loss: 0.1833 - mrcnn_bbox_loss: 0.0904 - mrcnn_mask_loss: 0.1271 - val_loss: 0.5446 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.1416 - val_mrcnn_class_loss: 0.1798 - val_mrcnn_bbox_loss: 0.0934 - val_mrcnn_mask_loss: 0.1264
# Epoch 49/100
# 1000/1000 [==============================] - 686s 686ms/step - loss: 0.5497 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1472 - mrcnn_class_loss: 0.1808 - mrcnn_bbox_loss: 0.0905 - mrcnn_mask_loss: 0.1283 - val_loss: 0.5673 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.1497 - val_mrcnn_class_loss: 0.1936 - val_mrcnn_bbox_loss: 0.0910 - val_mrcnn_mask_loss: 0.1301
# Epoch 50/100
# 1000/1000 [==============================] - 680s 680ms/step - loss: 0.5529 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1469 - mrcnn_class_loss: 0.1865 - mrcnn_bbox_loss: 0.0903 - mrcnn_mask_loss: 0.1262 - val_loss: 0.5452 - val_rpn_class_loss: 0.0027 - val_rpn_bbox_loss: 0.1464 - val_mrcnn_class_loss: 0.1803 - val_mrcnn_bbox_loss: 0.0890 - val_mrcnn_mask_loss: 0.1268
# Epoch 51/100
# 1000/1000 [==============================] - 677s 677ms/step - loss: 0.5587 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.1500 - mrcnn_class_loss: 0.1876 - mrcnn_bbox_loss: 0.0911 - mrcnn_mask_loss: 0.1268 - val_loss: 0.5897 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.1547 - val_mrcnn_class_loss: 0.2013 - val_mrcnn_bbox_loss: 0.0961 - val_mrcnn_mask_loss: 0.1347
# Epoch 52/100
# 1000/1000 [==============================] - 669s 669ms/step - loss: 0.5494 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.1469 - mrcnn_class_loss: 0.1844 - mrcnn_bbox_loss: 0.0900 - mrcnn_mask_loss: 0.1252 - val_loss: 0.5634 - val_rpn_class_loss: 0.0033 - val_rpn_bbox_loss: 0.1547 - val_mrcnn_class_loss: 0.1832 - val_mrcnn_bbox_loss: 0.0931 - val_mrcnn_mask_loss: 0.1290
# Epoch 53/100
# 1000/1000 [==============================] - 680s 680ms/step - loss: 0.5520 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.1477 - mrcnn_class_loss: 0.1860 - mrcnn_bbox_loss: 0.0892 - mrcnn_mask_loss: 0.1263 - val_loss: 0.5584 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.1436 - val_mrcnn_class_loss: 0.1922 - val_mrcnn_bbox_loss: 0.0915 - val_mrcnn_mask_loss: 0.1283
# Epoch 54/100
# 1000/1000 [==============================] - 688s 688ms/step - loss: 0.5457 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.1466 - mrcnn_class_loss: 0.1839 - mrcnn_bbox_loss: 0.0879 - mrcnn_mask_loss: 0.1243 - val_loss: 0.5477 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.1498 - val_mrcnn_class_loss: 0.1785 - val_mrcnn_bbox_loss: 0.0916 - val_mrcnn_mask_loss: 0.1249
# Epoch 55/100
# 1000/1000 [==============================] - 684s 684ms/step - loss: 0.5527 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.1500 - mrcnn_class_loss: 0.1846 - mrcnn_bbox_loss: 0.0906 - mrcnn_mask_loss: 0.1246 - val_loss: 0.5331 - val_rpn_class_loss: 0.0027 - val_rpn_bbox_loss: 0.1471 - val_mrcnn_class_loss: 0.1771 - val_mrcnn_bbox_loss: 0.0862 - val_mrcnn_mask_loss: 0.1200
# Epoch 56/100
#  127/1000 [==>...........................] - ETA: 9:34 - loss: 0.5485 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.1447 - mrcnn_class_loss: 0.1843 - mrcnn_bbox_loss: 0.0916 - mrcnn_mask_loss: 0.1249

# %%
model.keras_model.save_weights('C:/Users/yliu60/Documents/GitHub/Pixel-Embedding/logs/shapes_12_instances_100_epoch.h5')

# %% [markdown]
# # Evaluation

# %%
for i in np.linspace(0, 1, 11):
    inference_config.DETECTION_NMS_THRESHOLD = np.float32(i)
    model = modellib.MaskRCNN(mode="inference", 
                              config=inference_config,
                              model_dir=MODEL_DIR)

    current_epoch = 100

    # Load trained weights
    model_path = os.path.join('C:\\Users\\yliu60\\Documents\\GitHub\\Pixel-Embedding\\logs\\3_shapes_100.h5')
    print("Loading weights from ", model_path)
    model.load_weights(model_path, by_name=True)

    dt_filename = 'shapes.json'
    result_list = get_mrcnn_result_list(model, config)

    with open(os.path.join(config.DT_DIR, dt_filename), 'w') as outfile:
        json.dump(result_list, outfile)

    config.GT_JSON_DIR = 'C:\\Users\\yliu60\\Documents\\GitHub\\Pixel-Embedding\\gt_json\\deeplabv3\\6\\shapes_val_small_6_[1, 2, 3].json'

    args = params_lib.Args()

    args.num_shape_per_class = None
    args.dt_dir              = config.DT_DIR
    args.gt_dir              = config.GT_JSON_DIR
    args.maxProp             = int(1000)
    args.outputFile          = 'output'

    metrics = batchEval.main(args)

    print("NMS threshold: {}".format(i))
    ap            = metrics['both'].ap
    ap50          = metrics['both'].ap_05
    ap75          = metrics['both'].ap_075
    ar100         = metrics['both'].ar100
    ar_none       = metrics['both'].ar_none
    ar_partial    = metrics['both'].ar_partial
    ar_heavy      = metrics['both'].ar_heavy
    string_format = "{:.4f} & {:.4f} & {:.4f} & {:.4f} & {:.4f} & {:.4f} & {:.4f} \\\\ \n \\hline"
    print(string_format.format(
        ap, ap50, ap75, ar100, ar_none, ar_partial, ar_heavy))

# %% [markdown]
# # Examples

# %%
for _ in range(4):
    image_id = random.choice(dataset_val.image_ids)
    print('image_id = {}'.format(image_id))
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)

    log("original_image", original_image)
    log("image_meta", image_meta)
    log("gt_class_id", gt_class_id)
    log("gt_bbox", gt_bbox)
    log("gt_mask", gt_mask)

    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset_val.class_names, figsize=(8, 8))

    results = model.detect([original_image], verbose=0)

    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset_val.class_names, r['scores'], ax=get_ax())
